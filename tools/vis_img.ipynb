# %%
import torch
import numpy as np
logits = torch.load("logits.pt")[0, 0, :, :].cpu().numpy()
target = torch.load("target.pt")[0, 0, :, :].cpu().numpy()

# %%
print(logits.shape, target.shape)
# Out:
# (1533, 2912) (1533, 2912)

# %%
logits[np.where(logits<0)] = 0

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_title("mask.png")
ax1.imshow(logits, cmap='gray')
ax2.set_title("inklabels.png")
ax2.imshow(target, cmap='gray')
plt.show()
